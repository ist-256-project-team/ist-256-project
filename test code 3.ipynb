# %%
#first test if google translation works
#do not edit
from google.cloud import translate

translate_client = translate.Client()

text = "你好"
target = 'en'
translation = translate_client.translate(
    text,
    target_language=target)

print(u'Text: {}'.format(text))
print(u'Translation: {}'.format(translation['translatedText']))
# Out:
# Text: 你好
# Translation: Hello there

# %%
#putting 2 person together, try this after one way conversation works
#one way conversation doesn't work right now
#problem: it takes a long time to read the text and the input of the beginning of the loop uses the output
#possible solution: wait several seconds at the beginning before taking voice input
language_b = "zh-CN"
language_a = "en"
#start loop
#Google speech to text api
while True:   
#first person (english to chinese)
    import speech_recognition as sr
    try:
        r = sr.Recognizer()
        with sr.Microphone() as source:
            print("Say something!")
            audio = r.listen(source)

            print("You said: " + r.recognize_google(audio))
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))

    speech = r.recognize_google(audio)
    #translation API 


    from google.cloud import translate

    translate_client = translate.Client()

    text = speech
    if text=='goodbye':
        break
    target = language_b
    translation = translate_client.translate(
        text,
        target_language=target)

    print(u'Text: {}'.format(text))
    print(u'Translation: {}'.format(translation['translatedText'])) 
    translated_text=translation['translatedText']

    from gtts import gTTS
    tts=gTTS(translated_text,lang="zh-cn")
    tts.save('new.mp3')
    from pygame import mixer
    mixer.init()
    mixer.music.load('new.mp3')
    mixer.music.play()
    # second person (chinese to english)
    import speech_recognition as sr
    try:
        r = sr.Recognizer()
        with sr.Microphone() as source:
            print("Say something!")
            audio = r.listen(source)

            print("You said: " + r.recognize_google(audio))
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))

    speech = r.recognize_google(audio)
    #translation API 


    from google.cloud import translate

    translate_client = translate.Client()

    text = speech
    if text=='goodbye':
        break
    if text=='Google Speech Recognition could not understand audio':
        break
    
    target = language_b
    translation = translate_client.translate(
        text,
        target_language=target)

    print(u'Text: {}'.format(text))
    print(u'Translation: {}'.format(translation['translatedText'])) 
    translated_text=translation['translatedText']

    from gtts import gTTS
    tts=gTTS(translated_text,lang="zh-cn")
    tts.save('new.mp3')
    from pygame import mixer
    mixer.init()
    mixer.music.load('new.mp3')
    mixer.music.play()
# Out:
# Say something!
# You said: bubo bubo bubo
# Text: bubo bubo bubo
# Translation: 溢出溢出的溢出物
# Say something!
# You said: Eataly 232
# Text: Eataly 232
# Translation: Eataly 232
# Say something!
# You said: goodbye

# %%
#first person (english to chinese)+second person
#test
#one loop
language_b = "zh-CN"
language_a = "en"
#first person
import speech_recognition as sr
while True:
    try:
        r = sr.Recognizer()
        with sr.Microphone() as source:
            print("Say something!")
            audio = r.listen(source)
            text_from_langinput_a = r.recognize_google(audio,language=language_a)
            print("You said: " + text_from_langinput_a)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
        text_from_langinput_a='Google Speech Recognition could not understand audio'
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))


    #translation API 


    from google.cloud import translate

    translate_client = translate.Client()

    
    if text_from_langinput_a=='goodbye':
        break
    if text_from_langinput_a=='Google Speech Recognition could not understand audio':
        continue
    target = language_b
    translation = translate_client.translate(
        text_from_langinput_a,
        target_language=target)

    
    print(u'Translation: {}'.format(translation['translatedText'])) 
    translated_text=translation['translatedText']
    text_from_langinput_b=='goodbye'
    
    from gtts import gTTS
    tts=gTTS(translated_text,lang=language_b)
    tts.save('new.mp3')
    from pygame import mixer
    mixer.init()
    mixer.music.load('new.mp3')
    mixer.music.play()
 #second person   
    try:
        r = sr.Recognizer()
        with sr.Microphone() as source:
            print("Say something!")
            audio = r.listen(source)
            text_from_langinput_b = r.recognize_google(audio,language=language_b)
            print("You said: " + text_from_langinput_b)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
        text_from_langinput_b='Google Speech Recognition could not understand audio'
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))


    #translation API 


    from google.cloud import translate

    translate_client = translate.Client()

    

    target = language_a
    translation = translate_client.translate(
        text_from_langinput_b,
        target_language=target)

    
    print(u'Translation: {}'.format(translation['translatedText'])) 
    translated_text=translation['translatedText']
    if translated_text=='Goodbye':
        break
    if translated_text=='Google Speech Recognition could not understand audio':
        continue 
    
    from gtts import gTTS
    tts=gTTS(translated_text,lang=language_a)
    tts.save('new.mp3')
    from pygame import mixer
    mixer.init()
    mixer.music.load('new.mp3')
    mixer.music.play()

# %%
#first person (english to chinese)
language_b = "zh-CN"
language_a = "en"
import speech_recognition as sr
while True:
    try:
        r = sr.Recognizer()
        with sr.Microphone() as source:
            print("Say something!")
            audio = r.listen(source)
            text_from_langinput_a = r.recognize_google(audio,language=language_a)
            print("You said: " + text_from_langinput_a)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
        text_from_langinput_a='Google Speech Recognition could not understand audio'
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))


    #translation API 


    from google.cloud import translate

    translate_client = translate.Client()

    
    if text_from_langinput_a=='goodbye':
        break
    if text_from_langinput_a=='Google Speech Recognition could not understand audio':
        continue
    target = language_b
    translation = translate_client.translate(
        text_from_langinput_a,
        target_language=target)

    
    print(u'Translation: {}'.format(translation['translatedText'])) 
    translated_text=translation['translatedText']
    text_from_langinput_b=='goodbye'
    
    from gtts import gTTS
    tts=gTTS(translated_text,lang=language_b)
    tts.save('new.mp3')
    from pygame import mixer
    mixer.init()
    mixer.music.load('new.mp3')
    mixer.music.play()
# Out:
# Say something!
# You said: hello
# Translation: 你好
# Say something!
# You said: that song
# Translation: 那首歌
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: okay so it's like
# Translation: 好吧就是这样
# Say something!
# You said: goodbye

# %%
# test if try except works  # conclusion: google voice recognition try-except works
#do try except with translation api
import speech_recognition as sr
try:
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Say something!")
        audio = r.listen(source)

        print("You said: " + r.recognize_google(audio))
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))
# Out:
# Say something!
# Google Speech Recognition could not understand audio

# %%
# second person (chinese to english)
language_b = "zh-CN"
language_a = "en"
import speech_recognition as sr
while True:
    try:
        r = sr.Recognizer()
        with sr.Microphone() as source:
            print("Say something!")
            audio = r.listen(source)
            text_from_langinput_b = r.recognize_google(audio,language=language_b)
            print("You said: " + text_from_langinput_b)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
        text_from_langinput_b='Google Speech Recognition could not understand audio'
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))


    #translation API 


    from google.cloud import translate

    translate_client = translate.Client()

    

    target = language_a
    translation = translate_client.translate(
        text_from_langinput_b,
        target_language=target)

    
    print(u'Translation: {}'.format(translation['translatedText'])) 
    translated_text=translation['translatedText']
    if translated_text=='Goodbye':
        break
    if translated_text=='Google Speech Recognition could not understand audio':
        continue 
    
    from gtts import gTTS
    tts=gTTS(translated_text,lang=language_a)
    tts.save('new.mp3')
    from pygame import mixer
    mixer.init()
    mixer.music.load('new.mp3')
    mixer.music.play()
# Out:
# Say something!
# You said: 你好
# Translation: Hello there
# Say something!
# You said: 再见
# Translation: Goodbye

# %%
#original code. copy this to edit
#generate ISO code for language
import pandas as pd
data = pd.read_html('https://cloud.google.com/translate/docs/languages')
language_df=data[0]

language_dict = language_df.to_dict(orient='records')
#get a list of full language name, the list is called ful_lag
ful_lag=[]
for language in language_dict:
    ful_lag.append(language['Language'])
ful_lag[13]='Chinese_S'
ful_lag[14]='Chinese_T'
#ful_lag
#get a list of abbreviated language name, the list is called abr_lag
abr_lag=[]
for language in language_dict:
    abr_lag.append(language['ISO-639-1 Code'])
#abr_lag
#make a dictionary with "full language name" as the key and "abbreviated language name" as the value
lag_dict={}
for n in range(len(abr_lag)):
    lag_dict[ful_lag[n]]=abr_lag[n]
lag_dict['Chinese_S']='zh-CN'
lag_dict['Chinese_T']='zh-TW'

#code body
while True:   
    language_one=input('Before you begin your phone call, enter your language: ')
    if language_one=='stop':
        break
    if language_one in lag_dict:  
        ISO_Code_1=lag_dict[language_one]
        language_a = ISO_Code_1
        print(ISO_Code_1)
        break
    else:
        print('Invalid Entry, please try again.')
while True: 
    if language_one != 'stop':
        language_two=input('Before you begin your phone call, enter the language of the recipient: ')
        if language_two=='stop':
            break
        if language_two in lag_dict:  
            ISO_Code=lag_dict[language_two]
            language_b = ISO_Code
            print(ISO_Code)
            break
        else:
            print('Invalid Entry, please try again.')
# Out:
# Before you begin your phone call, enter your language: English
# en
# Before you begin your phone call, enter the language of the recipient: Chinese
# Invalid Entry, please try again.
# Before you begin your phone call, enter the language of the recipient: Chinese_S
# zh-CN

# %%
#original code. copy this to edit
#speech to text + translation + text to speech
language_b = "zh-CN"
language_a = "en"
#start loop
#Google speech to text api
import speech_recognition as sr
try:
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Say something!")
        audio = r.listen(source)

        print("You said: " + r.recognize_google(audio))
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))

speech = r.recognize_google(audio)
#translation API 


from google.cloud import translate

translate_client = translate.Client()

text = speech
target = language_b
translation = translate_client.translate(
    text,
    target_language=target)

print(u'Text: {}'.format(text))
print(u'Translation: {}'.format(translation['translatedText'])) 
translated_text=translation['translatedText']
    
from gtts import gTTS
tts=gTTS(translated_text,lang="zh-cn")
tts.save('new.mp3')
from pygame import mixer
mixer.init()
mixer.music.load('new.mp3')
mixer.music.play()
# Out:
# Say something!
# You said: hello
# Text: hello
# Translation: 你好

# %%
import pyttsx3
engine = pyttsx3.init()
voice_ID=[]
voice_lag=[]
voices = engine.getProperty('voices')
for voice in voices:
    voice_ID.append(voice.id)
    voice_lag.append(voice.languages)
voice_dict={}
for n in range(len(voice_lag)):
    voice_dict[voice_lag[n]]=voice_ID[n]
voice_dict
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-c034c1bc6d93> in <module>()
#       9 voice_dict={}
#      10 for n in range(len(voice_lag)):
# ---> 11     voice_dict[voice_lag[n]]=voice_ID[n]
#      12 voice_dict
#      13
#
# TypeError: unhashable type: 'list'

# %%
import pandas as pd
data = pd.read_html('https://cloud.google.com/translate/docs/languages')
language_df=data[0]

language_dict = language_df.to_dict(orient='records')
#get a list of full language name, the list is called ful_lag
ful_lag=[]
for language in language_dict:
    ful_lag.append(language['Language'])
ful_lag[13]='Chinese_S'
ful_lag[14]='Chinese_T'
#ful_lag
#get a list of abbreviated language name, the list is called abr_lag
abr_lag=[]
for language in language_dict:
    abr_lag.append(language['ISO-639-1 Code'])
#abr_lag
#make a dictionary with "full language name" as the key and "abbreviated language name" as the value
lag_dict={}
for n in range(len(abr_lag)):
    lag_dict[ful_lag[n]]=abr_lag[n]
lag_dict['Chinese_S']='zh-CN'
lag_dict['Chinese_T']='zh-TW'

#code body
while True:   
    language_a=input('Before you begin your phone call, enter your language: ')
    if language_a=='stop':
        break
    if language_a in lag_dict:  
        ISO_Code_1=lag_dict[language_a]
        language_b = ISO_Code_1
        print(ISO_Code_1)
        break
    else:
        print('Invalid Entry, please try again.')
while True: 
    if language_a != 'stop':
        language_c=input('Before you begin your phone call, enter the language of the recipient: ')
        if language_c=='stop':
            break
        if language_two in lag_dict:  
            ISO_Code=lag_dict[language_c]
            language_d = ISO_Code
            print(ISO_Code)
            break
        else:
            print('Invalid Entry, please try again.')
#start loop
#Google speech to text api
while True:
    
#translation API 
from google.cloud import translate

translate_client = translate.Client()

text = speech
target = language_d
translation = translate_client.translate(
    text,
    target_language=target)

print(u'Text: {}'.format(text))
print(u'Translation: {}'.format(translation['translatedText']))

# %%
#google translation api
from google.cloud import translate

translate_client = translate.Client()

text = speech
target = 'en'
translation = translate_client.translate(
    text,
    target_language=target)

print(u'Text: {}'.format(text))
print(u'Translation: {}'.format(translation['translatedText']))
#text to speech api
new_text=translation['translatedText']
# Out:
# Text: 第1个API能将中文语音转化为文本
# Translation: The first API can convert Chinese voice into text

# %%
#text to speech api
#new_text=translation['translatedText']
import pyttsx3
engine = pyttsx3.init()
engine.setProperty('voice', "com.apple.speech.synthesis.voice.ting-ting")
engine.say('你好')
engine.runAndWait()
#voice output

# %%
import pyttsx3
engine = pyttsx3.init()
voice_ID=[]
voice_lag=[]
voices = engine.getProperty('voices')
for voice in voices:
    voice_ID.append(voice.id)
    voice_lag.append(voice.languages)
voice_lag[0]
# Out:
# ['en_US']

# %%
#Another google cloud speech to text api

from __future__ import division

import re
import sys

from google.cloud import speech
from google.cloud.speech import enums
from google.cloud.speech import types
import pyaudio
from six.moves import queue

RATE = 16000
CHUNK = int(RATE / 10)  # 100ms


class MicrophoneStream(object):
    """Opens a recording stream as a generator yielding the audio chunks."""
    def __init__(self, rate, chunk):
        self._rate = rate
        self._chunk = chunk

        # Create a thread-safe buffer of audio data
        self._buff = queue.Queue()
        self.closed = True

    def __enter__(self):
        self._audio_interface = pyaudio.PyAudio()
        self._audio_stream = self._audio_interface.open(
            format=pyaudio.paInt16,
            
            channels=1, rate=self._rate,
            input=True, frames_per_buffer=self._chunk,
            # Run the audio stream asynchronously to fill the buffer object.
            # This is necessary so that the input device's buffer doesn't
            # overflow while the calling thread makes network requests, etc.
            stream_callback=self._fill_buffer,
        )

        self.closed = False

        return self

    def __exit__(self, type, value, traceback):
        self._audio_stream.stop_stream()
        self._audio_stream.close()
        self.closed = True
        # Signal the generator to terminate so that the client's
        # streaming_recognize method will not block the process termination.
        self._buff.put(None)
        self._audio_interface.terminate()

    def _fill_buffer(self, in_data, frame_count, time_info, status_flags):
        """Continuously collect data from the audio stream, into the buffer."""
        self._buff.put(in_data)
        return None, pyaudio.paContinue

    def generator(self):
        while not self.closed:
            # Use a blocking get() to ensure there's at least one chunk of
            # data, and stop iteration if the chunk is None, indicating the
            # end of the audio stream.
            chunk = self._buff.get()
            if chunk is None:
                return
            data = [chunk]

            # Now consume whatever other data's still buffered.
            while True:
                try:
                    chunk = self._buff.get(block=False)
                    if chunk is None:
                        return
                    data.append(chunk)
                except queue.Empty:
                    break

            yield b''.join(data)


def listen_print_loop(responses):
    """Iterates through server responses and prints them.

    The responses passed is a generator that will block until a response
    is provided by the server.

    Each response may contain multiple results, and each result may contain
    multiple alternatives; for details, see https://goo.gl/tjCPAU.  Here we
    print only the transcription for the top alternative of the top result.

    In this case, responses are provided for interim results as well. If the
    response is an interim one, print a line feed at the end of it, to allow
    the next result to overwrite it, until the response is a final one. For the
    final one, print a newline to preserve the finalized transcription.
    """
    num_chars_printed = 0
    for response in responses:
        if not response.results:
            continue

        # The `results` list is consecutive. For streaming, we only care about
        # the first result being considered, since once it's `is_final`, it
        # moves on to considering the next utterance.
        result = response.results[0]
        if not result.alternatives:
            continue

        # Display the transcription of the top alternative.
        transcript = result.alternatives[0].transcript

        # Display interim results, but with a carriage return at the end of the
        # line, so subsequent lines will overwrite them.
        #
        # If the previous result was longer than this one, we need to print
        # some extra spaces to overwrite the previous result
        overwrite_chars = ' ' * (num_chars_printed - len(transcript))

        if not result.is_final:
            sys.stdout.write(transcript + overwrite_chars + '\r')
            sys.stdout.flush()

            num_chars_printed = len(transcript)

        else:
            print(transcript + overwrite_chars)

            # Exit recognition if any of the transcribed phrases could be
            # one of our keywords.
            if re.search(r'\b(exit|quit)\b', transcript, re.I):
                print('Exiting..')
                break

            num_chars_printed = 0


def main():
    # See http://g.co/cloud/speech/docs/languages
    # for a list of supported languages.
    language_code = 'en-US'  # a BCP-47 language tag

    client = speech.SpeechClient()
    config = types.RecognitionConfig(
        encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
        sample_rate_hertz=RATE,
        language_code=language_code)
    streaming_config = types.StreamingRecognitionConfig(
        config=config,
        interim_results=True)

    with MicrophoneStream(RATE, CHUNK) as stream:
        audio_generator = stream.generator()
        requests = (types.StreamingRecognizeRequest(audio_content=content)
                    for content in audio_generator)

        responses = client.streaming_recognize(streaming_config, requests)

        # Now, put the transcription responses to use.
        listen_print_loop(responses)


if __name__ == '__main__':
    main()
# Out:
# this is another API that converts speech into text
#  quit
# Exiting..
